# %%
from averager import *
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
to_average = 5 * np.random.random((100, 100, 100))

diff_radiuses = [2, 8, 16, 32]

# %%
time_basic_parallel = [[],[],[],[],[]]
time_gauss = []

# %%
for radius in diff_radiuses:
    for max_processes in range(1, 17):
        print("max_proc = " + str(max_processes) + ", radius = " + str(radius))
        time_start = time.time()
        result = basic_3d_array_averaging_parallel(to_average, radius, max_processes, True)
        time_end = time.time()
        print("basic time = " + str(time_end - time_start))
        time_basic_parallel[diff_radiuses.index(radius)].append(time_end - time_start)
    time_start = time.time()
    result = average_3d_by_gauss(to_average, radius)
    time_end = time.time()
    print("gauss time = " + str(time_end - time_start))
    time_gauss.append(time_end - time_start)
# Out:
# max_proc = 1, radius = 2
# 100%|██████████| 1000000/1000000 [00:06<00:00, 145918.38it/s]
# basic time = 7.871609449386597
# max_proc = 2, radius = 2
# 100%|██████████| 1000000/1000000 [00:03<00:00, 261627.14it/s]
# basic time = 4.7540037631988525
# max_proc = 3, radius = 2
# 100%|██████████| 1000000/1000000 [00:02<00:00, 346219.14it/s]
# basic time = 3.785576105117798
# max_proc = 4, radius = 2
# 100%|██████████| 1000000/1000000 [00:02<00:00, 431507.61it/s]
# basic time = 3.282467842102051
# max_proc = 5, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 540823.41it/s]
# basic time = 2.7657384872436523
# max_proc = 6, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 592643.84it/s]
# basic time = 2.5698745250701904
# max_proc = 7, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 654490.04it/s]
# basic time = 2.4258670806884766
# max_proc = 8, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 635218.51it/s]
# basic time = 2.528871536254883
# max_proc = 9, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 688115.03it/s]
# basic time = 2.3751649856567383
# max_proc = 10, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 737435.80it/s]
# basic time = 2.2398109436035156
# max_proc = 11, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 730257.11it/s]
# basic time = 2.239696741104126
# max_proc = 12, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 779043.79it/s]
# basic time = 2.2007546424865723
# max_proc = 13, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 715306.00it/s]
# basic time = 2.343559503555298
# max_proc = 14, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 723864.88it/s]
# basic time = 2.3923397064208984
# max_proc = 15, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 730116.90it/s]
# basic time = 2.303548574447632
# max_proc = 16, radius = 2
# 100%|██████████| 1000000/1000000 [00:01<00:00, 699810.31it/s]
# basic time = 2.3862340450286865
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       8     time_basic_parallel[diff_radiuses.index(radius)].append(time_end - time_start)
#       9 time_start = time.time()
# ---> 10 result = gauss_3d(to_average, radius)
#      11 time_end = time.time()
#      12 print("gauss time = " + str(time_end - time_start))
#
# NameError: name 'gauss_3d' is not defined

# %%
name = ['radius = 2', 'radius = 8', 'radius = 16', 'radius = 32']

# %%
x_axis = range(1, 17)
fig0 = plt.figure()
for i in range(3):
    plt.scatter(x_axis, time_basic_parallel[i], label = name[i])
plt.xlabel("number of processes")
plt.ylabel("time, seconds")
plt.title("Time dependence on radius")
plt.legend()
plt.show
fig1 = plt.figure()
for i in range(4):
    plt.scatter(x_axis, time_basic_parallel[i], label = name[i])
plt.xlabel("number of processes")
plt.ylabel("time, seconds")
plt.title("Time dependence on processes")
plt.legend()
plt.show
fig2 = plt.figure()
plt.plot(diff_radiuses, time_gauss)
plt.xlabel("averaging radius")
plt.ylabel("time, seconds")
plt.title("Time dependence on processes")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
